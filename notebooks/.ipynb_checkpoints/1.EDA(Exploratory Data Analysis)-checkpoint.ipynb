# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
dataset = pd.read_csv(r"D:\Study\Credit-Card-Fraud-Detection-System\data\creditcard.csv")

# %%
dataset.shape
# Out:
# (284807, 31)

# %%
dataset.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
print("Missing values: ", dataset.isnull().sum().sum())
# Out:
# Missing values:  0

# %%
pd.set_option('display.float_format', lambda x:'%.6f'%x)

# %%
print("Basic Stats: ")
dataset.describe()
# Out:
# Basic Stats:
#                Time            V1            V2            V3            V4  \
# count 284807.000000 284807.000000 284807.000000 284807.000000 284807.000000
# mean   94813.859575      0.000000      0.000000     -0.000000      0.000000
# std    47488.145955      1.958696      1.651309      1.516255      1.415869
# min        0.000000    -56.407510    -72.715728    -48.325589     -5.683171
# 25%    54201.500000     -0.920373     -0.598550     -0.890365     -0.848640
# 50%    84692.000000      0.018109      0.065486      0.179846     -0.019847
# 75%   139320.500000      1.315642      0.803724      1.027196      0.743341
# max   172792.000000      2.454930     22.057729      9.382558     16.875344
#
#                  V5            V6            V7            V8            V9  \
# count 284807.000000 284807.000000 284807.000000 284807.000000 284807.000000
# mean       0.000000      0.000000     -0.000000      0.000000     -0.000000
# ...

# %% [markdown]
# ### Class distribution(fraud vs legit)

# %%
count = dataset["Class"].value_counts()
print("Note:\n O represents legitimate while 1 represents fraud:")
print(count)
print("\n Fraud rate: ", count[1]/count.sum()*100, "%")
# Out:
# Note:
#  O represents legitimate while 1 represents fraud:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
#
#  Fraud rate:  0.1727485630620034 %

# %%
count.plot(kind = "bar", color = ['green', 'red'])
plt.xticks([0, 1],['Legitimate', 'Fraud'], rotation = 0)
plt.title('Legitimate vs Fraud Transactions')
plt.ylabel('Counts')
plt.show()

# %%
Legit = dataset[dataset['Class']==0]
Fraud = dataset[dataset['Class']==1]
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.hist(Legit['Amount'], bins= 50, color='green')
plt.title('Legit Transactions Amount')
plt.xlabel('Amount')
plt.grid(True)

plt.subplot(1,2,2)
plt.hist(Fraud['Amount'], bins= 50, color='red')
plt.title('Fraud Transactions Amount')
plt.xlabel('Amount')
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,7))
sample = dataset.sample(10000, random_state=42)
sns.heatmap(sample.corr(), cmap='coolwarm', linewidths=0.1, center=0)
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
sample.cov()
# Out:
#                     Time          V1           V2            V3           V4  \
# Time   2231127457.516135 9943.112400 -1766.890280 -29109.748049 -6848.151812
# V1           9943.112400    4.183049     0.406802      0.039249    -0.082118
# V2          -1766.890280    0.406802     3.249031      0.011656    -0.163974
# V3         -29109.748049    0.039249     0.011656      2.275665    -0.003487
# V4          -6848.151812   -0.082118    -0.163974     -0.003487     1.967360
# V5          13047.011628   -0.195387    -0.379910     -0.068476     0.088096
# V6          -5210.646947    0.228816     0.225279      0.054830    -0.061713
# V7           4713.591615    0.134611     0.275879      0.032695    -0.022828
# V8          -2741.384548   -0.151298     0.063172     -0.092620     0.044609
# V9             12.801627   -0.046245    -0.009413     -0.038453     0.025305
# V10           924.537678   -0.071759     0.035377     -0.051250     0.004370
# ...

# %% [markdown]
# ## Key Observations
# - Dataset has ~284k transactions, only ~0.17% are fraud → heavily imbalanced
# - Features V1–V28 are already PCA-transformed (anonymized)
# - Amount and Time are the only raw features
# - Fraud transactions tend to be smaller amounts
# - We'll need SMOTE to handle the class imbalance
